# %%
import os
import pandas as pd


results = {} 
print(os.getcwd())
nameForCsv = os.getcwd().split("/")[5] + "-" + os.getcwd().split("/")[6]

dirFiles = os.listdir(".")
dirFiles.sort()
for filename in dirFiles:
    listTestFailed = []     
    inside = 0
    if 'resultat' in filename:

        with open(filename, 'r') as file:
            lines = file.readlines()
            #Taking the last 23 lines of the big crush results file 
            last_lines = lines[-23:]
            for line in last_lines:
                #Tests failed are listed between "---------" character. We take here failed tests.
                #We parse failed tests and add it in listTestFailed  
                if(inside == 1 and '------' not in line):
                    listTestFailed.append(line.split()[0] + ":" + line.split()[1])
                if(('-------' in line) and inside == 0):
                    inside = 1
                    
                elif(('-------' in line) and inside == 1):
                    inside = 0
                    break
        #Mts000M00xxxx.txt is 17 character long. We take this part of the filename has key value.        
        results[filename[-17:]] = listTestFailed
    


#This line going to fail if MT status has failed more than the columns number tests in Big Crush. 
#You can had or remove column a,b,c,d,e,f,g,...
df = pd.DataFrame.from_dict(results, columns=["a","b","c","d","e","f"] , orient='index')
df.index.name = 'File name'

df = df.sort_index()
print(df)
print("#################")

dfGoodStatus = df.loc[(df["c"].isnull())] 
dfGoodStatus = dfGoodStatus.sort_index()
print(dfGoodStatus)
dfGoodStatus.to_csv("goodStatus"+nameForCsv+".csv")
print("#################")

dfBadStatus = df.loc[(df["c"].notnull())] 
dfBadStatus = dfBadStatus.sort_index()
print(dfBadStatus)
dfBadStatus.to_csv("badStatus"+nameForCsv+".csv")
print("#################")

nb3FailedTest = len(dfBadStatus[dfBadStatus["d"].isnull()]) 

nb4FailedTest = len(dfBadStatus[dfBadStatus["d"].notnull() & dfBadStatus["e"].isnull()]) 

nb5FailedTest = len(dfBadStatus[dfBadStatus["e"].notnull() & dfBadStatus["f"].isnull()])

nb6FailedTest = len(dfBadStatus[dfBadStatus["f"].notnull()])

print("Number of status that failed 3 tests : " + str(nb3FailedTest))
print("Number of status that failed 4 tests : " + str(nb4FailedTest))
print("Number of status that failed 5 tests : " + str(nb5FailedTest))
print("Number of status that failed 6 tests : " + str(nb6FailedTest))

countAcolumn = dfBadStatus["a"].value_counts().reset_index()
countAcolumn.columns = ["testName","count"] 
countBcolumn = dfBadStatus["b"].value_counts().reset_index()
countBcolumn.columns = ["testName","count"] 
countCcolumn = dfBadStatus["c"].value_counts().reset_index()
countCcolumn.columns = ["testName","count"] 
countDcolumn = dfBadStatus["d"].value_counts().reset_index()
countDcolumn.columns = ["testName","count"] 
countEcolumn = dfBadStatus["e"].value_counts().reset_index()
countEcolumn.columns = ["testName","count"] 
countFcolumn = dfBadStatus["f"].value_counts().reset_index()
countFcolumn.columns = ["testName","count"] 

print(countAcolumn)
print(countBcolumn)
print(countCcolumn)
print(countDcolumn)
print(countEcolumn)
print(countFcolumn)

print("###################################")

dfCount = pd.concat([countAcolumn,countBcolumn,countCcolumn,countDcolumn,countEcolumn,countFcolumn]).groupby(["testName"]).sum().reset_index()
print(dfCount.to_string())
dfCount.to_csv("dfCount"+nameForCsv+".csv")

print(dfCount.sort_values(by="count",ascending=False))
dfCount.sort_values(by="count",ascending=False).to_csv("dfCountDescending"+nameForCsv+".csv")

print(nameForCsv)
# Out:
# /home/local.isima.fr/beantunes/These/testU01-hpcsmp/SlurmIndexSeq
#                                    a               b                   c  \
# File name
# Mts000M000000.txt     80:LinearComp,  81:LinearComp,                None
# Mts000M000001.txt     80:LinearComp,  81:LinearComp,                None
# Mts000M000002.txt     80:LinearComp,  81:LinearComp,                None
# Mts000M000003.txt     80:LinearComp,  81:LinearComp,                None
# Mts000M000004.txt     80:LinearComp,  81:LinearComp,                None
# ...                              ...             ...                 ...
# Mts000M004091.txt     80:LinearComp,  81:LinearComp,                None
# Mts000M004092.txt     80:LinearComp,  81:LinearComp,                None
# Mts000M004093.txt  11:CollisionOver,  80:LinearComp,      81:LinearComp,
# Mts000M004094.txt     80:LinearComp,  81:LinearComp,  91:HammingWeight2,
# Mts000M004095.txt     80:LinearComp,  81:LinearComp,                None
#
#                       d     e     f
# File name
# Mts000M000000.txt  None  None  None
# Mts000M000001.txt  None  None  None
# Mts000M000002.txt  None  None  None
# Mts000M000003.txt  None  None  None
# Mts000M000004.txt  None  None  None
# ...                 ...   ...   ...
# Mts000M004091.txt  None  None  None
# Mts000M004092.txt  None  None  None
# Mts000M004093.txt  None  None  None
# Mts000M004094.txt  None  None  None
# Mts000M004095.txt  None  None  None
#
# [4096 rows x 6 columns]
# #################
#                                 a               b     c     d     e     f
# File name
# Mts000M000000.txt  80:LinearComp,  81:LinearComp,  None  None  None  None
# Mts000M000001.txt  80:LinearComp,  81:LinearComp,  None  None  None  None
# Mts000M000002.txt  80:LinearComp,  81:LinearComp,  None  None  None  None
# Mts000M000003.txt  80:LinearComp,  81:LinearComp,  None  None  None  None
# Mts000M000004.txt  80:LinearComp,  81:LinearComp,  None  None  None  None
# ...                           ...             ...   ...   ...   ...   ...
# Mts000M004087.txt  80:LinearComp,  81:LinearComp,  None  None  None  None
# Mts000M004089.txt  80:LinearComp,  81:LinearComp,  None  None  None  None
# Mts000M004091.txt  80:LinearComp,  81:LinearComp,  None  None  None  None
# Mts000M004092.txt  80:LinearComp,  81:LinearComp,  None  None  None  None
# Mts000M004095.txt  80:LinearComp,  81:LinearComp,  None  None  None  None
#
# [2941 rows x 6 columns]
# #################
#                                    a               b                   c  \
# File name
# Mts000M000008.txt     74:RandomWalk1  80:LinearComp,      81:LinearComp,
# Mts000M000018.txt     79:RandomWalk1  80:LinearComp,      81:LinearComp,
# Mts000M000019.txt     52:SampleProd,  80:LinearComp,      81:LinearComp,
# Mts000M000023.txt      24:ClosePairs  80:LinearComp,      81:LinearComp,
# Mts000M000029.txt  11:CollisionOver,  80:LinearComp,      81:LinearComp,
# ...                              ...             ...                 ...
# Mts000M004084.txt  64:WeightDistrib,  80:LinearComp,      81:LinearComp,
# Mts000M004088.txt      24:ClosePairs  80:LinearComp,      81:LinearComp,
# Mts000M004090.txt     79:RandomWalk1  80:LinearComp,      81:LinearComp,
# Mts000M004093.txt  11:CollisionOver,  80:LinearComp,      81:LinearComp,
# Mts000M004094.txt     80:LinearComp,  81:LinearComp,  91:HammingWeight2,
#
#                       d     e     f
# File name
# Mts000M000008.txt  None  None  None
# Mts000M000018.txt  None  None  None
# Mts000M000019.txt  None  None  None
# Mts000M000023.txt  None  None  None
# Mts000M000029.txt  None  None  None
# ...                 ...   ...   ...
# Mts000M004084.txt  None  None  None
# Mts000M004088.txt  None  None  None
# Mts000M004090.txt  None  None  None
# Mts000M004093.txt  None  None  None
# Mts000M004094.txt  None  None  None
#
# [1155 rows x 6 columns]
# #################
# Number of status that failed 3 tests : 966
# Number of status that failed 4 tests : 169
# Number of status that failed 5 tests : 18
# Number of status that failed 6 tests : 2
#              testName  count
# 0      80:LinearComp,    182
# 1   11:CollisionOver,     61
# 2   12:CollisionOver,     51
# 3      74:RandomWalk1     48
# 4       24:ClosePairs     44
# ..                ...    ...
# 79    65:SumCollector      3
# 80   5:CollisionOver,      3
# 81         47:MaxOft,      2
# 82   6:CollisionOver,      2
# 83   3:CollisionOver,      2
#
# [84 rows x 2 columns]
#                   testName  count
# 0           80:LinearComp,    843
# 1           81:LinearComp,    175
# 2           74:RandomWalk1     14
# 3           78:RandomWalk1     13
# 4           75:RandomWalk1      9
# 5           79:RandomWalk1      8
# 6            22:ClosePairs      8
# 7           76:RandomWalk1      6
# 8            24:ClosePairs      6
# 9           53:SampleMean,      5
# 10          77:RandomWalk1      5
# 11           23:ClosePairs      4
# 12               48:MaxOft      4
# 13           25:ClosePairs      4
# 14               47:MaxOft      4
# 15         65:SumCollector      3
# 16          56:SampleCorr,      3
# 17       60:WeightDistrib,      3
# 18               46:MaxOft      2
# 19              49:MaxOft,      2
# 20          68:MatrixRank,      2
# 21       59:WeightDistrib,      2
# 22          55:SampleCorr,      2
# 23          52:SampleProd,      2
# 24    18:BirthdaySpacings,      1
# 25          51:SampleProd,      1
# 26          66:MatrixRank,      1
# 27       11:CollisionOver,      1
# 28           27:SimpPoker,      1
# 29          67:MatrixRank,      1
# 30       62:WeightDistrib,      1
# 31                  73:GCD      1
# 32           29:SimpPoker,      1
# 33  58:AppearanceSpacings,      1
# 34       12:CollisionOver,      1
# 35     32:CouponCollector,      1
# 36          54:SampleMean,      1
# 37         41:Permutation,      1
# 38          70:MatrixRank,      1
# 39                 37:Gap,      1
# 40              48:MaxOft,      1
# 41         43:Permutation,      1
# 42     30:CouponCollector,      1
# 43           26:SimpPoker,      1
# 44                 36:Gap,      1
# 45         40:Permutation,      1
# 46               72:Savir2      1
# 47       64:WeightDistrib,      1
# 48       61:WeightDistrib,      1
# 49    15:BirthdaySpacings,      1
#                 testName  count
# 0         81:LinearComp,    850
# 1         80:LinearComp,    126
# 2        93:HammingCorr,     13
# 3       96:HammingIndep,     13
# 4      100:HammingIndep,     10
# 5       95:HammingIndep,      9
# 6          82:LempelZiv,      8
# 7           103:AutoCor,      8
# 8        94:HammingCorr,      8
# 9           104:AutoCor,      8
# 10    86:LongestHeadRun,      8
# 11          105:AutoCor,      7
# 12               101:Run      7
# 13         83:LempelZiv,      7
# 14  88:PeriodsInStrings,      7
# 15          106:AutoCor,      7
# 16      98:HammingIndep,      7
# 17      99:HammingIndep,      6
# 18               102:Run      6
# 19      97:HammingIndep,      5
# 20    87:LongestHeadRun,      4
# 21    91:HammingWeight2,      4
# 22    90:HammingWeight2,      4
# 23        77:RandomWalk1      3
# 24  89:PeriodsInStrings,      3
# 25       92:HammingCorr,      3
# 26          85:Fourier3,      3
# 27        74:RandomWalk1      2
# 28        78:RandomWalk1      2
# 29        51:SampleProd,      1
# 30             72:Savir2      1
# 31        56:SampleCorr,      1
# 32     61:WeightDistrib,      1
# 33        75:RandomWalk1      1
# 34        79:RandomWalk1      1
# 35        55:SampleCorr,      1
#                 testName  count
# 0         81:LinearComp,    129
# 1         80:LinearComp,     13
# 2        92:HammingCorr,      4
# 3                102:Run      4
# 4     86:LongestHeadRun,      4
# 5       95:HammingIndep,      3
# 6       99:HammingIndep,      3
# 7           103:AutoCor,      3
# 8          82:LempelZiv,      3
# 9       96:HammingIndep,      2
# 10      97:HammingIndep,      2
# 11          85:Fourier3,      2
# 12               101:Run      2
# 13    87:LongestHeadRun,      2
# 14     100:HammingIndep,      2
# 15    90:HammingWeight2,      2
# 16  88:PeriodsInStrings,      2
# 17          84:Fourier3,      1
# 18       94:HammingCorr,      1
# 19      98:HammingIndep,      1
# 20        79:RandomWalk1      1
# 21          106:AutoCor,      1
# 22  89:PeriodsInStrings,      1
# 23          104:AutoCor,      1
#              testName  count
# 0      81:LinearComp,     13
# 1  86:LongestHeadRun,      2
# 2    95:HammingIndep,      1
# 3        104:AutoCor,      1
# 4    99:HammingIndep,      1
# 5      80:LinearComp,      1
# 6  87:LongestHeadRun,      1
#           testName  count
# 0  93:HammingCorr,      1
# 1   81:LinearComp,      1
# ###################################
#                    testName  count
# 0         100:HammingIndep,     12
# 1                   101:Run      9
# 2                   102:Run     10
# 3              103:AutoCor,     11
# 4              104:AutoCor,     10
# 5              105:AutoCor,      7
# 6              106:AutoCor,      8
# 7         10:CollisionOver,     24
# 8         11:CollisionOver,     62
# 9         12:CollisionOver,     52
# 10     13:BirthdaySpacings,      5
# 11     14:BirthdaySpacings,      8
# 12     15:BirthdaySpacings,      5
# 13     16:BirthdaySpacings,      7
# 14     17:BirthdaySpacings,      8
# 15     18:BirthdaySpacings,      5
# 16     19:BirthdaySpacings,      6
# 17            1:SerialOver,      8
# 18     20:BirthdaySpacings,      5
# 19     21:BirthdaySpacings,     10
# 20            22:ClosePairs     44
# 21            23:ClosePairs     39
# 22            24:ClosePairs     50
# 23            25:ClosePairs     43
# 24            26:SimpPoker,      9
# 25            27:SimpPoker,      6
# 26            28:SimpPoker,      8
# 27            29:SimpPoker,      7
# 28            2:SerialOver,      8
# 29      30:CouponCollector,      8
# 30      31:CouponCollector,      7
# 31      32:CouponCollector,      7
# 32      33:CouponCollector,      4
# 33                  34:Gap,      9
# 34                  35:Gap,      8
# 35                  36:Gap,     10
# 36                  37:Gap,      5
# 37                  38:Run,     13
# 38                  39:Run,      9
# 39         3:CollisionOver,      2
# 40          40:Permutation,      5
# 41          41:Permutation,     12
# 42          42:Permutation,     10
# 43          43:Permutation,      5
# 44      44:CollisionPermut,      3
# 45      45:CollisionPermut,      5
# 46                46:MaxOft      9
# 47               46:MaxOft,      9
# 48                47:MaxOft     10
# 49               47:MaxOft,      2
# 50                48:MaxOft     10
# 51               48:MaxOft,      9
# 52                49:MaxOft      9
# 53               49:MaxOft,      5
# 54         4:CollisionOver,      9
# 55           50:SampleProd,      5
# 56           51:SampleProd,      9
# 57           52:SampleProd,      7
# 58           53:SampleMean,     10
# 59           54:SampleMean,      5
# 60           55:SampleCorr,     11
# 61           56:SampleCorr,     14
# 62   57:AppearanceSpacings,      8
# 63   58:AppearanceSpacings,      4
# 64        59:WeightDistrib,     10
# 65         5:CollisionOver,      3
# 66        60:WeightDistrib,     11
# 67        61:WeightDistrib,     12
# 68        62:WeightDistrib,     10
# 69        63:WeightDistrib,     11
# 70        64:WeightDistrib,      5
# 71          65:SumCollector      6
# 72           66:MatrixRank,      9
# 73           67:MatrixRank,     11
# 74           68:MatrixRank,      9
# 75           69:MatrixRank,      4
# 76         6:CollisionOver,      2
# 77           70:MatrixRank,      7
# 78           71:MatrixRank,      5
# 79                72:Savir2     10
# 80                   73:GCD      9
# 81           74:RandomWalk1     64
# 82           75:RandomWalk1     43
# 83           76:RandomWalk1     48
# 84           77:RandomWalk1     37
# 85           78:RandomWalk1     38
# 86           79:RandomWalk1     39
# 87         7:CollisionOver,      6
# 88           80:LinearComp,   1165
# 89           81:LinearComp,   1168
# 90            82:LempelZiv,     11
# 91            83:LempelZiv,      7
# 92             84:Fourier3,      1
# 93             85:Fourier3,      5
# 94       86:LongestHeadRun,     14
# 95       87:LongestHeadRun,      7
# 96     88:PeriodsInStrings,      9
# 97     89:PeriodsInStrings,      4
# 98         8:CollisionOver,      9
# 99       90:HammingWeight2,      6
# 100      91:HammingWeight2,      4
# 101         92:HammingCorr,      7
# 102         93:HammingCorr,     14
# 103         94:HammingCorr,      9
# 104        95:HammingIndep,     13
# 105        96:HammingIndep,     15
# 106        97:HammingIndep,      7
# 107        98:HammingIndep,      8
# 108        99:HammingIndep,     10
# 109        9:CollisionOver,     21
#                testName  count
# 89       81:LinearComp,   1168
# 88       80:LinearComp,   1165
# 81       74:RandomWalk1     64
# 8     11:CollisionOver,     62
# 9     12:CollisionOver,     52
# ..                  ...    ...
# 44  44:CollisionPermut,      3
# 49           47:MaxOft,      2
# 76     6:CollisionOver,      2
# 39     3:CollisionOver,      2
# 92         84:Fourier3,      1
#
# [110 rows x 2 columns]
# testU01-hpcsmp-SlurmIndexSeq
