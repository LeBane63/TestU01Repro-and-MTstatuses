# %%
import os
import pandas as pd


results = {} 
for filename in os.listdir(os.getcwd()):
    listTestFailed = [] 
    inside = 0
    if 'resultatNode' in filename:
        with open(filename, 'r') as file:
            lines = file.readlines()
            last_lines = lines[-23:]
            for line in last_lines:
                
                if(inside == 1 and '------' not in line and "r = " in line):
                    listTestFailed.append(line.split()[0] + ":" + line.split()[1])
                if(('-------' in line) and inside == 0):
                    inside = 1
                    
                elif(('-------' in line) and inside == 1):
                    inside = 0
                    break
                
        results[filename[-17:]] = listTestFailed
    


#This line going to fail if Mt status has failed more than 4 tests in Big Crush, but on 4096 status it didn't happen
df = pd.DataFrame.from_dict(results, columns=["a","b","c","d"] , orient='index')
df.index.name = 'File name'


print(df)
print("#################")

dfGoodStatus = df.loc[(df["c"].isnull()) &  (df["d"].isnull())] 
print(dfGoodStatus)
print("#################")

dfBadStatus = df.loc[(df["c"].notnull()) |  (df["d"].notnull())] 
print(dfBadStatus)
print("#################")
# Out:
#                                                     a               b     c  \
# File name
# resultatNode36StatusMts000M003795.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode37StatusMts000M001487.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode37StatusMts000M001507.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode36StatusMts000M004018.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode36StatusMts000M002962.txt  80:LinearComp,  81:LinearComp,  None
# ...                                               ...             ...   ...
# resultatNode37StatusMts000M001428.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode36StatusMts000M002966.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode36StatusMts000M003835.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode37StatusMts000M001771.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode37StatusMts000M000895.txt  80:LinearComp,  81:LinearComp,  None
#
#                                           d
# File name
# resultatNode36StatusMts000M003795.txt  None
# resultatNode37StatusMts000M001487.txt  None
# resultatNode37StatusMts000M001507.txt  None
# resultatNode36StatusMts000M004018.txt  None
# resultatNode36StatusMts000M002962.txt  None
# ...                                     ...
# resultatNode37StatusMts000M001428.txt  None
# resultatNode36StatusMts000M002966.txt  None
# resultatNode36StatusMts000M003835.txt  None
# resultatNode37StatusMts000M001771.txt  None
# resultatNode37StatusMts000M000895.txt  None
#
# [4096 rows x 4 columns]
# #################
#                                                     a               b     c  \
# File name
# resultatNode36StatusMts000M003795.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode37StatusMts000M001487.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode37StatusMts000M001507.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode36StatusMts000M004018.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode36StatusMts000M002962.txt  80:LinearComp,  81:LinearComp,  None
# ...                                               ...             ...   ...
# resultatNode37StatusMts000M001428.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode36StatusMts000M002966.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode36StatusMts000M003835.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode37StatusMts000M001771.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode37StatusMts000M000895.txt  80:LinearComp,  81:LinearComp,  None
#
#                                           d
# File name
# resultatNode36StatusMts000M003795.txt  None
# resultatNode37StatusMts000M001487.txt  None
# resultatNode37StatusMts000M001507.txt  None
# resultatNode36StatusMts000M004018.txt  None
# resultatNode36StatusMts000M002962.txt  None
# ...                                     ...
# resultatNode37StatusMts000M001428.txt  None
# resultatNode36StatusMts000M002966.txt  None
# resultatNode36StatusMts000M003835.txt  None
# resultatNode37StatusMts000M001771.txt  None
# resultatNode37StatusMts000M000895.txt  None
#
# [3779 rows x 4 columns]
# #################
#                                                          a               b  \
# File name
# resultatNode37StatusMts000M000612.txt        28:SimpPoker,  80:LinearComp,
# resultatNode37StatusMts000M001870.txt       80:LinearComp,  81:LinearComp,
# resultatNode37StatusMts000M001326.txt       80:LinearComp,  81:LinearComp,
# resultatNode36StatusMts000M002785.txt       80:LinearComp,  81:LinearComp,
# resultatNode37StatusMts000M001166.txt              38:Run,  80:LinearComp,
# ...                                                    ...             ...
# resultatNode36StatusMts000M003984.txt        28:SimpPoker,  80:LinearComp,
# resultatNode36StatusMts000M003017.txt    60:WeightDistrib,  80:LinearComp,
# resultatNode36StatusMts000M002100.txt       80:LinearComp,  81:LinearComp,
# resultatNode36StatusMts000M002241.txt              34:Gap,  80:LinearComp,
# resultatNode36StatusMts000M002429.txt  30:CouponCollector,  80:LinearComp,
#
#                                                           c     d
# File name
# resultatNode37StatusMts000M000612.txt        81:LinearComp,  None
# resultatNode37StatusMts000M001870.txt        81:LinearComp,  None
# resultatNode37StatusMts000M001326.txt    86:LongestHeadRun,  None
# resultatNode36StatusMts000M002785.txt    87:LongestHeadRun,  None
# resultatNode37StatusMts000M001166.txt        81:LinearComp,  None
# ...                                                     ...   ...
# resultatNode36StatusMts000M003984.txt        81:LinearComp,  None
# resultatNode36StatusMts000M003017.txt        81:LinearComp,  None
# resultatNode36StatusMts000M002100.txt  88:PeriodsInStrings,  None
# resultatNode36StatusMts000M002241.txt        81:LinearComp,  None
# resultatNode36StatusMts000M002429.txt        81:LinearComp,  None
#
# [317 rows x 4 columns]
# #################
