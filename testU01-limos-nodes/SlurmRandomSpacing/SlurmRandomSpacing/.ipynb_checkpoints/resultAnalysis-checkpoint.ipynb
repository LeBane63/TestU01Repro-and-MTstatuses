# %%
import os
import pandas as pd


results = {} 
compteurLine = 0
listFile = os.listdir('.')
listFile.sort()
for filename in listFile:
    listTestFailed = [] 
    inside = 0
    if 'resultatNode' in filename:
        with open(filename, 'r') as file:
            lines = file.readlines()
            last_lines = lines[-23:]
            for line in last_lines:
                
                if(inside == 1 and '------' not in line and "r = " in line):
                    listTestFailed.append(line.split()[0] + ":" + line.split()[1])
                if(('-------' in line) and inside == 0):
                    inside = 1
                    
                elif(('-------' in line) and inside == 1):
                    inside = 0
                    break
                
        results[filename[-17:]] = listTestFailed
    


#This line going to fail if Mt status has failed more than 4 tests in Big Crush, but on 4096 status it didn't happen
df = pd.DataFrame.from_dict(results, columns=["a","b","c","d"] , orient='index')
df.index.name = 'File name'

df = df.sort_index()
print(df)
print("#################")

dfGoodStatus = df.loc[(df["c"].isnull()) &  (df["d"].isnull())] 
dfGoodStatus = dfGoodStatus.sort_index()
print(dfGoodStatus)
dfGoodStatus.to_csv("goodStatus.csv")
print("#################")

dfBadStatus = df.loc[(df["c"].notnull()) |  (df["d"].notnull())] 
dfBadStatus = dfBadStatus.sort_index()
print(dfBadStatus)
dfBadStatus.to_csv("badStatus.csv")
print("#################")
# Out:
#                                 a               b               c  \
# File name
# Mts000M000000.txt  80:LinearComp,  81:LinearComp,            None
# Mts000M000001.txt  80:LinearComp,  81:LinearComp,            None
# Mts000M000002.txt  80:LinearComp,  81:LinearComp,            None
# Mts000M000003.txt  80:LinearComp,  81:LinearComp,            None
# Mts000M000004.txt  80:LinearComp,  81:LinearComp,            None
# ...                           ...             ...             ...
# Mts000M004091.txt  53:SampleMean,  80:LinearComp,  81:LinearComp,
# Mts000M004092.txt  80:LinearComp,  81:LinearComp,            None
# Mts000M004093.txt  80:LinearComp,  81:LinearComp,            None
# Mts000M004094.txt  80:LinearComp,  81:LinearComp,            None
# Mts000M004095.txt  80:LinearComp,  81:LinearComp,            None
#
#                                     d
# File name
# Mts000M000000.txt                None
# Mts000M000001.txt                None
# Mts000M000002.txt                None
# Mts000M000003.txt                None
# Mts000M000004.txt                None
# ...                               ...
# Mts000M004091.txt  87:LongestHeadRun,
# Mts000M004092.txt                None
# Mts000M004093.txt                None
# Mts000M004094.txt                None
# Mts000M004095.txt                None
#
# [4096 rows x 4 columns]
# #################
#                                 a               b     c     d
# File name
# Mts000M000000.txt  80:LinearComp,  81:LinearComp,  None  None
# Mts000M000001.txt  80:LinearComp,  81:LinearComp,  None  None
# Mts000M000002.txt  80:LinearComp,  81:LinearComp,  None  None
# Mts000M000003.txt  80:LinearComp,  81:LinearComp,  None  None
# Mts000M000004.txt  80:LinearComp,  81:LinearComp,  None  None
# ...                           ...             ...   ...   ...
# Mts000M004090.txt  80:LinearComp,  81:LinearComp,  None  None
# Mts000M004092.txt  80:LinearComp,  81:LinearComp,  None  None
# Mts000M004093.txt  80:LinearComp,  81:LinearComp,  None  None
# Mts000M004094.txt  80:LinearComp,  81:LinearComp,  None  None
# Mts000M004095.txt  80:LinearComp,  81:LinearComp,  None  None
#
# [3751 rows x 4 columns]
# #################
#                                         a               b                   c  \
# File name
# Mts000M000018.txt       60:WeightDistrib,  80:LinearComp,      81:LinearComp,
# Mts000M000030.txt          80:LinearComp,  81:LinearComp,       83:LempelZiv,
# Mts000M000033.txt          80:LinearComp,  81:LinearComp,  87:LongestHeadRun,
# Mts000M000040.txt          80:LinearComp,  81:LinearComp,        85:Fourier3,
# Mts000M000043.txt       60:WeightDistrib,  80:LinearComp,      81:LinearComp,
# ...                                   ...             ...                 ...
# Mts000M004039.txt     32:CouponCollector,  80:LinearComp,      81:LinearComp,
# Mts000M004067.txt  58:AppearanceSpacings,  80:LinearComp,      81:LinearComp,
# Mts000M004075.txt       63:WeightDistrib,  80:LinearComp,      81:LinearComp,
# Mts000M004082.txt                 39:Run,  80:LinearComp,      81:LinearComp,
# Mts000M004091.txt          53:SampleMean,  80:LinearComp,      81:LinearComp,
#
#                                     d
# File name
# Mts000M000018.txt                None
# Mts000M000030.txt                None
# Mts000M000033.txt                None
# Mts000M000040.txt                None
# Mts000M000043.txt                None
# ...                               ...
# Mts000M004039.txt                None
# Mts000M004067.txt                None
# Mts000M004075.txt                None
# Mts000M004082.txt                None
# Mts000M004091.txt  87:LongestHeadRun,
#
# [345 rows x 4 columns]
# #################
