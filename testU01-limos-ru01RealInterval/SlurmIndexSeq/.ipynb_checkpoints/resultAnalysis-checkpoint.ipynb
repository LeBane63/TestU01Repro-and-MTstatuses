# %%
import os
import pandas as pd


results = {} 
for filename in os.listdir(os.getcwd()):
    listTestFailed = [] 
    inside = 0
    if 'resultatNode' in filename:
        with open(filename, 'r') as file:
            lines = file.readlines()
            last_lines = lines[-23:]
            for line in last_lines:
                
                if(inside == 1 and '------' not in line and "r = " in line):
                    listTestFailed.append(line.split()[0] + ":" + line.split()[1])
                if(('-------' in line) and inside == 0):
                    inside = 1
                    
                elif(('-------' in line) and inside == 1):
                    inside = 0
                    break
                
    results[filename] = listTestFailed
    


#This line going to fail if Mt status has failed more than 4 tests in Big Crush, but on 4096 status it didn't happen
df = pd.DataFrame.from_dict(results, columns=["a","b","c","d"] , orient='index')
df.index.name = 'File name'


print(df)
print("#################")

dfGoodStatus = df.loc[(df["c"].isnull()) &  (df["d"].isnull())] 
print(dfGoodStatus)
print("#################")

dfBadStatus = df.loc[(df["c"].notnull()) |  (df["d"].notnull())] 
print(dfBadStatus)
print("#################")
# Out:
# {'resultatNode36StatusMts000M003795.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode40StatusMts000M001588.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M002962.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode40StatusMts000M001049.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode40StatusMts000M000728.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M003239.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M003735.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M002552.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M002538.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M003507.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M003822.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M003451.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode40StatusMts000M001907.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M002985.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode40StatusMts000M001938.txt': [], 'resultatNode40StatusMts000M001697.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode40StatusMts000M001323.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode40StatusMts000M000269.txt': ['1:SerialOver,', '80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M003279.txt': ['80:LinearComp,', '81:LinearComp,'], 'Status-MT-8K-10p12': [], 'resultatNode40StatusMts000M000211.txt': ['44:CollisionPermut,', '80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M002785.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode40StatusMts000M001168.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode40StatusMts000M000770.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode40StatusMts000M001095.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode40StatusMts000M000299.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode40StatusMts000M001298.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M003937.txt': [], 'resultatNode40StatusMts000M000027.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M003254.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M003396.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode40StatusMts000M000496.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode40StatusMts000M001516.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M003762.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M002837.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M003132.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M002635.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode40StatusMts000M001756.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode40StatusMts000M000901.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M003402.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M002612.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M003816.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M003597.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M003392.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M002718.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M002753.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M003108.txt': ['44:CollisionPermut,', '80:LinearComp,', '81:LinearComp,'], 'resultatNode40StatusMts000M000227.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M003080.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode36StatusMts000M003884.txt': ['80:LinearComp,', '81:LinearComp,'], 'resultatNode40StatusMts000M002016.txt': [], 'resultatNode36StatusMts000M003497.txt': ['80:LinearComp,', '8 ...
#                                                     0               1     2  \
# File name
# resultatNode36StatusMts000M003795.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode40StatusMts000M001588.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode36StatusMts000M002962.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode40StatusMts000M001049.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode40StatusMts000M000728.txt  80:LinearComp,  81:LinearComp,  None
# ...                                               ...             ...   ...
# resultatNode40StatusMts000M000694.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode36StatusMts000M002966.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode40StatusMts000M000757.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode36StatusMts000M003835.txt  80:LinearComp,  81:LinearComp,  None
# resultatNode40StatusMts000M001758.txt  80:LinearComp,  81:LinearComp,  None
#
#                                           3
# File name
# resultatNode36StatusMts000M003795.txt  None
# resultatNode40StatusMts000M001588.txt  None
# resultatNode36StatusMts000M002962.txt  None
# resultatNode40StatusMts000M001049.txt  None
# resultatNode40StatusMts000M000728.txt  None
# ...                                     ...
# resultatNode40StatusMts000M000694.txt  None
# resultatNode36StatusMts000M002966.txt  None
# resultatNode40StatusMts000M000757.txt  None
# resultatNode36StatusMts000M003835.txt  None
# resultatNode40StatusMts000M001758.txt  None
#
# [3571 rows x 4 columns]
