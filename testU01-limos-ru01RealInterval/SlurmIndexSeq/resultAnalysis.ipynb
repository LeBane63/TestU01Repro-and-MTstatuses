# %%
import os
import pandas as pd


results = {} 
print(os.getcwd())
nameForCsv = os.getcwd().split("/")[5] + "-" + os.getcwd().split("/")[6]

dirFiles = os.listdir(".")
dirFiles.sort()
for filename in dirFiles:
    listTestFailed = []     
    inside = 0
    if 'resultat' in filename:

        with open(filename, 'r') as file:
            lines = file.readlines()
            #Taking the last 23 lines of the big crush results file 
            last_lines = lines[-23:]
            for line in last_lines:
                #Tests failed are listed between "---------" character. We take here failed tests.
                #We parse failed tests and add it in listTestFailed  
                if(inside == 1 and '------' not in line):
                    splitted = line.split()
                    testNumber = splitted[0]
                    testName = splitted[1].replace(",","")
                    string = testNumber + ":" + testName
                    if not (string in listTestFailed):
                        listTestFailed.append(string)
                if(('-------' in line) and inside == 0):
                    inside = 1
                    
                elif(('-------' in line) and inside == 1):
                    inside = 0
                    break
        #Mts000M00xxxx.txt is 17 character long. We take this part of the filename has key value.        
        results[filename[-17:]] = listTestFailed
    


#This line going to fail if MT status has failed more than the columns number tests in Big Crush. 
#You can had or remove column a,b,c,d,e,f,g,...
df = pd.DataFrame.from_dict(results, columns=["a","b","c","d","e"] , orient='index')
df.index.name = 'File name'

df = df.sort_index()
print(df)
print("#################")

dfGoodStatus = df.loc[(df["c"].isnull())] 
dfGoodStatus = dfGoodStatus.sort_index()
print(dfGoodStatus)
dfGoodStatus.to_csv("goodStatus"+nameForCsv+".csv")
print("#################")

dfBadStatus = df.loc[(df["c"].notnull())] 
dfBadStatus = dfBadStatus.sort_index()
print(dfBadStatus)
dfBadStatus.to_csv("badStatus"+nameForCsv+".csv")
print("#################")

nb3FailedTest = len(dfBadStatus[dfBadStatus["d"].isnull()]) 

nb4FailedTest = len(dfBadStatus[dfBadStatus["d"].notnull() & dfBadStatus["e"].isnull()]) 

nb5FailedTest = len(dfBadStatus[dfBadStatus["e"].notnull()])



print("Number of status that failed 3 tests : " + str(nb3FailedTest))
print("Number of status that failed 4 tests : " + str(nb4FailedTest))
print("Number of status that failed 5 tests : " + str(nb5FailedTest))


countAcolumn = dfBadStatus["a"].value_counts().reset_index()
countAcolumn.columns = ["testName","count"] 
countBcolumn = dfBadStatus["b"].value_counts().reset_index()
countBcolumn.columns = ["testName","count"] 
countCcolumn = dfBadStatus["c"].value_counts().reset_index()
countCcolumn.columns = ["testName","count"] 
countDcolumn = dfBadStatus["d"].value_counts().reset_index()
countDcolumn.columns = ["testName","count"] 
countEcolumn = dfBadStatus["e"].value_counts().reset_index()
countEcolumn.columns = ["testName","count"] 


print(countAcolumn)
print(countBcolumn)
print(countCcolumn)
print(countDcolumn)
print(countEcolumn)


print("###################################")

dfCount = pd.concat([countAcolumn,countBcolumn,countCcolumn,countDcolumn,countEcolumn]).groupby(["testName"]).sum().reset_index()
print(dfCount.to_string())
dfCount.to_csv("dfCount"+nameForCsv+".csv")

print(dfCount.sort_values(by="count",ascending=False))
dfCount.sort_values(by="count",ascending=False).to_csv("dfCountDescending"+nameForCsv+".csv")

print(nameForCsv)
# Out:
# /home/local.isima.fr/beantunes/These/testU01-limos-ru01RealInterval/SlurmIndexSeq
#                                   a              b                  c     d  \
# File name
# Mts000M000000.txt     80:LinearComp  81:LinearComp               None  None
# Mts000M000001.txt     80:LinearComp  81:LinearComp               None  None
# Mts000M000002.txt     80:LinearComp  81:LinearComp               None  None
# Mts000M000003.txt     80:LinearComp  81:LinearComp               None  None
# Mts000M000004.txt     80:LinearComp  81:LinearComp               None  None
# ...                             ...            ...                ...   ...
# Mts000M004091.txt     80:LinearComp  81:LinearComp               None  None
# Mts000M004092.txt     80:LinearComp  81:LinearComp               None  None
# Mts000M004093.txt  11:CollisionOver  80:LinearComp      81:LinearComp  None
# Mts000M004094.txt     80:LinearComp  81:LinearComp  91:HammingWeight2  None
# Mts000M004095.txt     80:LinearComp  81:LinearComp               None  None
#
#                       e
# File name
# Mts000M000000.txt  None
# Mts000M000001.txt  None
# Mts000M000002.txt  None
# Mts000M000003.txt  None
# Mts000M000004.txt  None
# ...                 ...
# Mts000M004091.txt  None
# Mts000M004092.txt  None
# Mts000M004093.txt  None
# Mts000M004094.txt  None
# Mts000M004095.txt  None
#
# [4096 rows x 5 columns]
# #################
#                                a              b     c     d     e
# File name
# Mts000M000000.txt  80:LinearComp  81:LinearComp  None  None  None
# Mts000M000001.txt  80:LinearComp  81:LinearComp  None  None  None
# Mts000M000002.txt  80:LinearComp  81:LinearComp  None  None  None
# Mts000M000003.txt  80:LinearComp  81:LinearComp  None  None  None
# Mts000M000004.txt  80:LinearComp  81:LinearComp  None  None  None
# ...                          ...            ...   ...   ...   ...
# Mts000M004087.txt  80:LinearComp  81:LinearComp  None  None  None
# Mts000M004089.txt  80:LinearComp  81:LinearComp  None  None  None
# Mts000M004091.txt  80:LinearComp  81:LinearComp  None  None  None
# Mts000M004092.txt  80:LinearComp  81:LinearComp  None  None  None
# Mts000M004095.txt  80:LinearComp  81:LinearComp  None  None  None
#
# [2968 rows x 5 columns]
# #################
#                                   a              b                  c     d  \
# File name
# Mts000M000008.txt    74:RandomWalk1  80:LinearComp      81:LinearComp  None
# Mts000M000019.txt     52:SampleProd  80:LinearComp      81:LinearComp  None
# Mts000M000023.txt     24:ClosePairs  80:LinearComp      81:LinearComp  None
# Mts000M000029.txt  11:CollisionOver  80:LinearComp      81:LinearComp  None
# Mts000M000038.txt     80:LinearComp  81:LinearComp  91:HammingWeight2  None
# ...                             ...            ...                ...   ...
# Mts000M004084.txt  64:WeightDistrib  80:LinearComp      81:LinearComp  None
# Mts000M004088.txt     24:ClosePairs  80:LinearComp      81:LinearComp  None
# Mts000M004090.txt    79:RandomWalk1  80:LinearComp      81:LinearComp  None
# Mts000M004093.txt  11:CollisionOver  80:LinearComp      81:LinearComp  None
# Mts000M004094.txt     80:LinearComp  81:LinearComp  91:HammingWeight2  None
#
#                       e
# File name
# Mts000M000008.txt  None
# Mts000M000019.txt  None
# Mts000M000023.txt  None
# Mts000M000029.txt  None
# Mts000M000038.txt  None
# ...                 ...
# Mts000M004084.txt  None
# Mts000M004088.txt  None
# Mts000M004090.txt  None
# Mts000M004093.txt  None
# Mts000M004094.txt  None
#
# [1128 rows x 5 columns]
# #################
# Number of status that failed 3 tests : 951
# Number of status that failed 4 tests : 158
# Number of status that failed 5 tests : 19
#                  testName  count
# 0           80:LinearComp    161
# 1        11:CollisionOver     61
# 2        12:CollisionOver     51
# 3          74:RandomWalk1     45
# 4           24:ClosePairs     44
# ..                    ...    ...
# 75     44:CollisionPermut      3
# 76  58:AppearanceSpacings      3
# 77        5:CollisionOver      3
# 78        6:CollisionOver      2
# 79        3:CollisionOver      2
#
# [80 rows x 2 columns]
#                  testName  count
# 0           80:LinearComp    835
# 1           81:LinearComp    161
# 2          78:RandomWalk1     15
# 3          74:RandomWalk1     12
# 4          79:RandomWalk1     10
# 5          75:RandomWalk1      8
# 6          76:RandomWalk1      7
# 7           22:ClosePairs      6
# 8          77:RandomWalk1      5
# 9               48:MaxOft      5
# 10          53:SampleMean      5
# 11          24:ClosePairs      4
# 12              47:MaxOft      4
# 13          56:SampleCorr      3
# 14          25:ClosePairs      3
# 15        65:SumCollector      3
# 16       60:WeightDistrib      3
# 17              46:MaxOft      3
# 18          23:ClosePairs      2
# 19          68:MatrixRank      2
# 20       59:WeightDistrib      2
# 21          55:SampleCorr      2
# 22          52:SampleProd      2
# 23              49:MaxOft      2
# 24       62:WeightDistrib      1
# 25       11:CollisionOver      1
# 26    18:BirthdaySpacings      1
# 27          67:MatrixRank      1
# 28       64:WeightDistrib      1
# 29     32:CouponCollector      1
# 30           27:SimpPoker      1
# 31           29:SimpPoker      1
# 32  58:AppearanceSpacings      1
# 33       12:CollisionOver      1
# 34           26:SimpPoker      1
# 35                 37:Gap      1
# 36                 73:GCD      1
# 37         41:Permutation      1
# 38          70:MatrixRank      1
# 39         43:Permutation      1
# 40          54:SampleMean      1
# 41       61:WeightDistrib      1
# 42     30:CouponCollector      1
# 43          51:SampleProd      1
# 44                 36:Gap      1
# 45         40:Permutation      1
# 46              72:Savir2      1
# 47    15:BirthdaySpacings      1
#                testName  count
# 0         81:LinearComp    835
# 1         80:LinearComp    120
# 2       96:HammingIndep     13
# 3        93:HammingCorr     12
# 4          82:LempelZiv      9
# 5      100:HammingIndep      9
# 6           104:AutoCor      9
# 7        94:HammingCorr      8
# 8     86:LongestHeadRun      8
# 9           103:AutoCor      8
# 10          106:AutoCor      7
# 11      97:HammingIndep      7
# 12      95:HammingIndep      7
# 13  88:PeriodsInStrings      7
# 14          105:AutoCor      7
# 15              101:Run      7
# 16      98:HammingIndep      6
# 17              102:Run      6
# 18         83:LempelZiv      6
# 19    91:HammingWeight2      5
# 20       92:HammingCorr      4
# 21    87:LongestHeadRun      4
# 22      99:HammingIndep      4
# 23  89:PeriodsInStrings      3
# 24    90:HammingWeight2      3
# 25       79:RandomWalk1      2
# 26       77:RandomWalk1      2
# 27       74:RandomWalk1      2
# 28          85:Fourier3      2
# 29        51:SampleProd      1
# 30            72:Savir2      1
# 31        56:SampleCorr      1
# 32       78:RandomWalk1      1
# 33     61:WeightDistrib      1
# 34        55:SampleCorr      1
#                testName  count
# 0         81:LinearComp    120
# 1         80:LinearComp     12
# 2        92:HammingCorr      4
# 3               102:Run      4
# 4     86:LongestHeadRun      4
# 5          82:LempelZiv      3
# 6       95:HammingIndep      3
# 7           103:AutoCor      3
# 8     90:HammingWeight2      3
# 9     87:LongestHeadRun      2
# 10      97:HammingIndep      2
# 11  88:PeriodsInStrings      2
# 12     100:HammingIndep      2
# 13              101:Run      2
# 14      99:HammingIndep      2
# 15          85:Fourier3      2
# 16      96:HammingIndep      2
# 17      98:HammingIndep      1
# 18          106:AutoCor      1
# 19  89:PeriodsInStrings      1
# 20       94:HammingCorr      1
# 21          84:Fourier3      1
#             testName  count
# 0      81:LinearComp     12
# 1  86:LongestHeadRun      2
# 2    95:HammingIndep      1
# 3     93:HammingCorr      1
# 4        104:AutoCor      1
# 5    99:HammingIndep      1
# 6  87:LongestHeadRun      1
# ###################################
#                   testName  count
# 0         100:HammingIndep     11
# 1                  101:Run      9
# 2                  102:Run     10
# 3              103:AutoCor     11
# 4              104:AutoCor     10
# 5              105:AutoCor      7
# 6              106:AutoCor      8
# 7         10:CollisionOver     24
# 8         11:CollisionOver     62
# 9         12:CollisionOver     52
# 10     13:BirthdaySpacings      5
# 11     14:BirthdaySpacings      8
# 12     15:BirthdaySpacings      5
# 13     16:BirthdaySpacings      7
# 14     17:BirthdaySpacings      8
# 15     18:BirthdaySpacings      5
# 16     19:BirthdaySpacings      6
# 17            1:SerialOver      8
# 18     20:BirthdaySpacings      5
# 19     21:BirthdaySpacings     10
# 20           22:ClosePairs     42
# 21           23:ClosePairs     37
# 22           24:ClosePairs     48
# 23           25:ClosePairs     42
# 24            26:SimpPoker      9
# 25            27:SimpPoker      6
# 26            28:SimpPoker      8
# 27            29:SimpPoker      7
# 28            2:SerialOver      8
# 29      30:CouponCollector      8
# 30      31:CouponCollector      7
# 31      32:CouponCollector      7
# 32      33:CouponCollector      4
# 33                  34:Gap      9
# 34                  35:Gap      8
# 35                  36:Gap     10
# 36                  37:Gap      5
# 37                  38:Run     13
# 38                  39:Run      9
# 39         3:CollisionOver      2
# 40          40:Permutation      5
# 41          41:Permutation     12
# 42          42:Permutation     10
# 43          43:Permutation      5
# 44      44:CollisionPermut      3
# 45      45:CollisionPermut      5
# 46               46:MaxOft     19
# 47               47:MaxOft     12
# 48               48:MaxOft     20
# 49               49:MaxOft     14
# 50         4:CollisionOver      9
# 51           50:SampleProd      5
# 52           51:SampleProd      9
# 53           52:SampleProd      7
# 54           53:SampleMean     10
# 55           54:SampleMean      6
# 56           55:SampleCorr     11
# 57           56:SampleCorr     14
# 58   57:AppearanceSpacings      8
# 59   58:AppearanceSpacings      4
# 60        59:WeightDistrib     10
# 61         5:CollisionOver      3
# 62        60:WeightDistrib     11
# 63        61:WeightDistrib     12
# 64        62:WeightDistrib     10
# 65        63:WeightDistrib     11
# 66        64:WeightDistrib      5
# 67         65:SumCollector      6
# 68           66:MatrixRank      9
# 69           67:MatrixRank     10
# 70           68:MatrixRank     10
# 71           69:MatrixRank      6
# 72         6:CollisionOver      2
# 73           70:MatrixRank      7
# 74           71:MatrixRank      5
# 75               72:Savir2     10
# 76                  73:GCD      8
# 77          74:RandomWalk1     59
# 78          75:RandomWalk1     38
# 79          76:RandomWalk1     46
# 80          77:RandomWalk1     36
# 81          78:RandomWalk1     38
# 82          79:RandomWalk1     41
# 83         7:CollisionOver      6
# 84           80:LinearComp   1128
# 85           81:LinearComp   1128
# 86            82:LempelZiv     12
# 87            83:LempelZiv      6
# 88             84:Fourier3      1
# 89             85:Fourier3      4
# 90       86:LongestHeadRun     14
# 91       87:LongestHeadRun      7
# 92     88:PeriodsInStrings      9
# 93     89:PeriodsInStrings      4
# 94         8:CollisionOver      9
# 95       90:HammingWeight2      6
# 96       91:HammingWeight2      5
# 97          92:HammingCorr      8
# 98          93:HammingCorr     13
# 99          94:HammingCorr      9
# 100        95:HammingIndep     11
# 101        96:HammingIndep     15
# 102        97:HammingIndep      9
# 103        98:HammingIndep      7
# 104        99:HammingIndep      7
# 105        9:CollisionOver     21
#               testName  count
# 85       81:LinearComp   1128
# 84       80:LinearComp   1128
# 8     11:CollisionOver     62
# 77      74:RandomWalk1     59
# 9     12:CollisionOver     52
# ..                 ...    ...
# 44  44:CollisionPermut      3
# 61     5:CollisionOver      3
# 39     3:CollisionOver      2
# 72     6:CollisionOver      2
# 88         84:Fourier3      1
#
# [106 rows x 2 columns]
# testU01-limos-ru01RealInterval-SlurmIndexSeq
